# %%
import requests

# %%
# https://httpbin.org/#/HTTP_Methods
payload = {
    'page':2,
    'count':25
}
r = requests.get('https://httpbin.org/get', params = payload)
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{\n  "args": {\n    "count": "25", \n    "page": "2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, zstd", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.34.2", \n    "X-Amzn-Trace-Id": "Root=1-6aa2c79d-6c25d0945cc9e3346f9a54ef"\n  }, \n  "origin": "124.217.188.174", \n  "url": "https://httpbin.org/get?page=2&count=25"\n}\n'

# %%
r.url
# Out:
# 'https://httpbin.org/get?page=2&count=25'

# %%
payload = {
    'username':'Ewen',
    'password':'Awesome'
}
r = requests.post('https://httpbin.org/post', data = payload)

# %%
r_dict = r.json()
r_dict
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'password': 'Awesome', 'username': 'Ewen'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, zstd',
#   'Content-Length': '30',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.34.2',
#   'X-Amzn-Trace-Id': 'Root=1-6aa2c79e-00ca3219714d8f2342759677'},
#  'json': None,
#  'origin': '124.217.188.174',
#  'url': 'https://httpbin.org/post'}

# %%
r_dict['form']
# Out:
# {'password': 'Awesome', 'username': 'Ewen'}
